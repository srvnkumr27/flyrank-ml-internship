# %% [markdown]
# <a href="https://colab.research.google.com/github/srvnkumr27/flyrank-ml-internship/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/srvnkumr27/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
#Lane 2: Refresh / Content Opportunity Scoring

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
'''Decision:
Which webpages should be prioritized for refresh, expansion, monitoring, protection, or pruning?

Who Acts on It:
Content managers, SEO specialists, and website content teams use the recommendations to decide where to focus their time and resources

Cost of a Wrong Recommendation:

* **False Positive:** Time and resources are spent reviewing or updating pages that did not need intervention.
* **False Negative:** High-potential or declining pages are ignored, which may lead to missed traffic, lower engagement, and lost business opportunities.

The goal is not to guarantee that a refresh will improve performance, but to help teams prioritize their efforts using data-driven insights.'''
# Out:
# 'Decision:\nWhich webpages should be prioritized for refresh, expansion, monitoring, protection, or pruning?\n\nWho Acts on It:\nContent managers, SEO specialists, and website content teams use the recommendations to decide where to focus their time and resources\n\nCost of a Wrong Recommendation:\n\n* **False Positive:** Time and resources are spent reviewing or updating pages that did not need intervention.\n* **False Negative:** High-potential or declining pages are ignored, which may lead to missed traffic, lower engagement, and lost business opportunities.\n\nThe goal is not to guarantee that a refresh will improve performance, but to help teams prioritize their efforts using data-driven insights.'

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# %pip -q install duckdb huggingface_hub

# %%
import os, getpass

# CI and power users set HF_TOKEN in the environment; everyone else gets the safe prompt.
HF_TOKEN = os.environ.get('HF_TOKEN') or getpass.getpass('Paste your Hugging Face READ token (hf_...): ')
# Out:
# Paste your Hugging Face READ token (hf_...): ··········

# %%
import duckdb

con = duckdb.connect()
con.execute(f"CREATE OR REPLACE SECRET hf (TYPE huggingface, TOKEN '{HF_TOKEN}')")

REL = 'hf://datasets/FlyRank/internship-warehouse'
TABLES = {
    'dim_clients':                f"read_parquet('{REL}/dim_clients.parquet')",
    'dim_content':                f"read_parquet('{REL}/dim_content.parquet')",
    'fact_daily':                 f"read_parquet('{REL}/fact_content_daily_performance/**/*.parquet')",
    'fact_daily_sample':          f"read_parquet('{REL}/fact_content_daily_performance_sample.parquet')",
    'fact_query_90d':             f"read_parquet('{REL}/fact_content_query_90d.parquet')",
}

for name, src in TABLES.items():
    n = con.sql(f'SELECT COUNT(*) FROM {src}').fetchone()[0]
    print(f'{name:22} {n:>12,} rows')
# Out:
# dim_clients                     104 rows
# dim_content                 519,606 rows
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# fact_daily               78,835,655 rows
# fact_daily_sample        11,694,072 rows
# fact_query_90d            2,414,248 rows

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
''' What My Work Will Be Able to Say

This project will provide observational and decision-support insights about which pages may deserve refresh, expansion, monitoring, protection, or pruning. It can identify patterns and directional relationships between content signals and page performance, helping content teams prioritize their efforts.

### What My Work Will Never Be Able to Say

This project will not provide causal proof that a particular action will improve performance. It cannot prove that refreshing a page will increase traffic, clicks, or engagement, and it does not predict or reverse-engineer Google's ranking algorithms. The recommendations should be treated as data-informed guidance rather than guarantees of future outcomes.
'''
# Out:
# " What My Work Will Be Able to Say\n\nThis project will provide observational and decision-support insights about which pages may deserve refresh, expansion, monitoring, protection, or pruning. It can identify patterns and directional relationships between content signals and page performance, helping content teams prioritize their efforts.\n\n### What My Work Will Never Be Able to Say\n\nThis project will not provide causal proof that a particular action will improve performance. It cannot prove that refreshing a page will increase traffic, clicks, or engagement, and it does not predict or reverse-engineer Google's ranking algorithms. The recommendations should be treated as data-informed guidance rather than guarantees of future outcomes.\n"

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
